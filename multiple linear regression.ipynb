# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('advertising.csv')

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
data.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
data.shape
# Out:
# (200, 4)

# %%
data['Sales'].shape
# Out:
# (200,)

# %%
data.plot(kind='scatter', x=['TV'], y='Sales')

data.plot(kind='scatter', x=['Radio'], y='Sales')

data.plot(kind='scatter', x=['Newspaper'], y='Sales')
# Out:
# <Axes: xlabel='[Newspaper]', ylabel='Sales'>

# %%
X = data[['TV', 'Radio', 'Newspaper']]
X.head(2)
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1

# %%
X.shape
# Out:
# (200, 3)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
y = data['Sales']
y.head(2)
# Out:
# 0    22.1
# 1    10.4
# Name: Sales, dtype: float64

# %%
print(y.shape)
# Out:
# (200,)

# %%
print(type(y))
# Out:
# <class 'pandas.core.series.Series'>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (150, 3)
# (150,)
# (50, 3)
# (50,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
# Out:
# 4.633808551125243

# %%
print(lr.coef_)
# Out:
# [0.05483762 0.10218027 0.00078783]

# %%
y_pred = lr.predict(X_test)

# %%
print(y_pred)
# Out:
# [21.29142142 18.04194205 10.03065109 21.04818991 20.75167113 24.52948332
#  16.85936471 15.69800653 10.17237239 18.90266535 15.82750789 10.53768469
#  18.86292327 15.57969067 17.89853384 15.35974564 13.76329903 21.00074026
#  10.03000895 19.20973979 11.12327234 12.18140998  8.67037889 11.96248005
#  12.63332284 16.83484748  9.75317608 21.06453498 18.075131   19.52477289
#  22.04440958 17.90745151 16.48534479 14.79190923 21.3573104  16.9364024
#  17.18742868 12.33688324 21.02974736  7.77584247  5.413222    9.64006117
#   6.91408859 19.22413789  7.93800502 15.16854596 13.73132724 21.01419263
#  20.49929224 20.57792216]

# %%
from sklearn import metrics

# %%
print("MAE:    ", metrics.mean_absolute_error(y_test, y_pred))
print("MSE:    ",metrics.mean_squared_error(y_test, y_pred))
print("RMSE:   ",np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE:     1.218790410701189
# MSE:     2.278925158685
# RMSE:    1.5096109295725835

# %% [markdown]
# # Result

# %% [markdown]
# The result seems reasonable, given that sales ranges from 5-25
